# %%
## after the finetuning folder is shared, Use the code below to mount the drive folder to colab
## Navigate to the appropriate folder to start reviewing and running the code

import os

from google.colab import drive
drive.mount('/content/drive')
print("Mounted Drive")

# Navigate to Folder containing the finetuning files. Make sure to update as needed
# %cd /content/drive/MyDrive/Colab Notebooks/finetuning-for-classification
# Out:
# Mounted at /content/drive
# Mounted Drive
# /content/drive/MyDrive/Colab Notebooks/finetuning-for-classification

# %%
# %run run_pipeline
# Out:
# ...
#                     NEWS CLASSIFICATION PIPELINE
# ...
#
# Loading API keys...
# ✓ Loaded HuggingFace token from ../secrets/hf_token.txt
# ✓ Loaded W&B API key from ../secrets/wandb_api_key.txt
#
#
# ...
# STEP 1: DATA PREPROCESSING AND BALANCING
# ...
# Loading data from JSON...
# Loaded 209527 total samples
#
# Original category distribution:
# category
# LIFESTYLE & WELLNESS    38773
# POLITICS                35602
# ENTERTAINMENT           17362
# NEWS                    15094
# TRAVEL                   9900
# PARENTING                8791
# FOOD & DRINK             8436
# BUSINESS & FINANCE       7748
# QUEER VOICES             6347
# COMEDY                   5400
# SPORTS                   5077
# BLACK VOICES             4583
# ENVIRONMENT              4066
# PARENTS                  3955
# WEDDINGS                 3653
# WOMEN                    3572
# CRIME                    3562
# IMPACT                   3484
# DIVORCE                  3426
# MEDIA                    2944
# ...
